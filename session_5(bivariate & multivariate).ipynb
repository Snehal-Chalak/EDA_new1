# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path="visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
visa_df["continent"].valuesc.ount()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4624\1159851504.py in ?()
# ----> 1 visa_df["continent"].valuesc.ount()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'valuesc'

# %% [markdown]
# - there are total 25480 aplicants are there
# - in that 25480 applicant 17018 applicant got the visa
# - 8462 applicant did not get visa
# - also there are 16861 aaplicant applied for visa from Asia
# - we want to know how many applicant from asia got certified
# - And how many applicant from asia got denined

# %%
# step-1: select the continent data
# step-2: continent data == 'Asia it is con1'
# step-3: select the case  staus data
# step-4:case statues data== 'Certified is com2
# step-5: con= con1 & con2
# step-6:apply main df on any get the len

# %%
#continent_data = ["continent"]

con1=visa_df["continent"]=="Asia"
con2=visa_df["case_status"]=="Certified"
con = con1 & con2
len(visa_df[con])
# Out:
# 11012

# %%
lables= visa_df["continent"].unique()
for i in lables:
    con1=visa_df["continent"]=="Asia"
    con2=visa_df["case_status"]=="Certified"
    
    con = con1 & con2
    visa_df[con].count()

# %%
lables= visa_df["continent"].unique()
certifide_count=[]
denide_count=[]
for i in lables:
    
    con1=visa_df["continent"]=="i"
    con2=visa_df["case_status"]=="Certified"
    con3=visa_df["case_status"]=="Denide"
    certi_count = con1 & con2
    den_count = con1& con2
    certifide_coun.append(len(visa_df[cert_count]))
    denide_count.append(len(visa_df[den_count]))
cols=sorted(visa_df["case_status"].unique())
print(cols)

pd.DataFrame(zip(certi_count,dencount),
             indes= lebles,
             colunms=cols)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 11
#       9     certi_count = con1 & con2
#      10     den_count = con1& con2
# ---> 11     certifide_coun.append(len(visa_df[cert_count]))
#      12     denide_count.append(len(visa_df[den_count]))
#      13 cols=sorted(visa_df["case_status"].unique())
#
# NameError: name 'certifide_coun' is not defined

# %% [markdown]
# ### cross Tab

# %%
col1=visa_df['continent']
col2=visa_df['case_status']
r1=pd.crosstab(col1,col2)

# %%
r1.plot()
# Out:
# <Axes: xlabel='continent'>

# %%
r1.plot(kind="bar")
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# ### case status-continent-education_of_employee

# %%
# from asia there 16k applicents apply for visa
#    in that 11k+ pppl are certified
    # in that 11k ppl different education appliants are available
    # we want those information

# %%
col1=visa_df["continent"]
col2=visa_df["case_status"]
col3=visa_df["education_of_employee"]
cols=[col2,col3]
r2=pd.crosstab(col1,cols)

# %%
r2
# Out:
# case_status            Certified                                    Denied  \
# education_of_employee Bachelor's Doctorate High School Master's Bachelor's
# continent
# Africa                        81        43          23      250         62
# Asia                        4407       780         676     5149       2761
# Europe                      1040       788         162      967        259
# North America                641       207         210      979        584
# Oceania                       38        19          19       46         28
# South America                160        75          74      184        173
#
# case_status
# education_of_employee Doctorate High School Master's
# continent
# Africa                       11          43       38
# Asia                        143        1614     1331
# Europe                       58         328      130
# North America                51         191      429
# Oceania                       3          17       22
# ...

# %%
r2.plot()
# Out:
# <Axes: xlabel='continent'>

# %%
r2.plot(kind="bar")
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# ### Group by

# %%
visa_df["education_of_employee"].value_counts()
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
visa_df["prevailing_wage"]
# wages are numerical values
# 25480 applicens are available
# diffrent applicent
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
visa_df.groupby("education_of_employee").count()
# Out:
#                        case_id  continent  has_job_experience  \
# education_of_employee
# Bachelor's               10234      10234               10234
# Doctorate                 2192       2192                2192
# High School               3420       3420                3420
# Master's                  9634       9634                9634
#
#                        requires_job_training  no_of_employees  yr_of_estab  \
# education_of_employee
# Bachelor's                             10234            10234        10234
# Doctorate                               2192             2192         2192
# High School                             3420             3420         3420
# Master's                                9634             9634         9634
#
#                        region_of_employment  prevailing_wage  unit_of_wage  \
# education_of_employee
# Bachelor's                            10234            10234         10234
# ...

# %%
visa_df.groupby("education_of_employee").size()
# Out:
# education_of_employee
# Bachelor's     10234
# Doctorate       2192
# High School     3420
# Master's        9634
# dtype: int64

# %%
# based on group by select an another column 
visa_df.groupby("education_of_employee")["prevailing_wage"]

# %%
visa_df["prevailing_wage"].mean()
# Out:
# np.float64(74455.81459209183)

# %%
visa_df[visa_df["education_of_employee"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 visa_df[visa_df["education_of_employee"]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# ...

# %%
con=visa_df["case_status"]=="Certified"
new_df=visa_df[con]
new_df.groupby('continent').size()

# %%
new_df.groupby('continent')["prevailing_wage"].mean()

# %%
- We have seen ...............

.
.
    .
    .
    .
    .
    .
    .
    .
    .
    .

# %% [markdown]
# **Plt.scatter**

# %%
x=range(0,11)
y=range(0,11)
plt.scatter(x,y)

# %%
x=range(0,11)
y=range(10,-1,-1) # 10 to -1+1=0
plt.scatter(x,y)
plt.plot(x,y)

# %%
x=range(0,11)
y=[5 for i in range(0,11)]
plt.scatter(x,y)
plt.plot(x,y)

# %%
y=range(0,11)
x=[5 for i in range(0,11)]
plt.scatter(x,y)
plt.plot(x,y)

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
.
.
.

# %%
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
col1=visa_df["no_of_employees"]
col2=visa_df["yr_of_estab"]
col3=visa_df["prevailing_wage"]
#plt.scatter(col1,col2)
plt.figure(figsize=(18,6))
plt.subplot(1,3,1).scatter(col1,col2)
plt.subplot(1,3,2).scatter(col2,col3)
plt.subplot(1,3,3).scatter(col1,col3)

# %%
path="winequality_red.csv"
wine_df=pd.read_csv(path)
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
cat1=wine_df.select_dtypes(include='object').columns
num1=wine_df.select_dtypes(exclude='object').columns

# %%
cat1
# Out:
# Index([], dtype='object')

# %%
num1
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
wine_df.corr(numeric_only=True)
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
visa_cor=visa_df.corr(numeric_only=True)
visa_cor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
col1=wine_df["fixed acidity"]
col2=wine_df["density"]
col3=wine_df["pH"]
#plt.scatter(col1,col2)
plt.figure(figsize=(18,6))
plt.subplot(1,3,1).scatter(col1,col2)
plt.subplot(1,3,2).scatter(col2,col3)
plt.subplot(1,3,3).scatter(col1,col3)

# %% [markdown]
# ### Heat map
# -

# %%
#visa_corr=visa_df.corr(numeric_only=True)

# %%
import seaborn as sns
sns.heatmap(visa_cor,annot=True)
# Out:
# <Axes: >

# %%
visa_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
col1=visa_df["free sulfur dioxide"]
col2=visa_df["total sulfur dioxide"]
col3=visa_df["fixed acidity"]
col4=visa_df["pH"]
col5=visa_df["citric acid"]
#plt.scatter(col1,col2)
plt.figure(figsize=(18,6))
plt.subplot(1,3,1).scatter(col1,col2)
plt.subplot(1,3,2).scatter(col3,col4)
plt.subplot(1,3,3).scatter(col1,col5)
#plt.subplot(1,3,4).scatter(col1,col3)
