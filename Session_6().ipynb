# %% [markdown]
# ### feature Engineering

# %%
- so far we performed feature analysis
     - Data frame qucik checks
     - Cetegorical column analaysis
     - Bar chart, Pie chart
     - Numerical  columns analaysis
     - Histograme , box plots, Outliers
     - Bi-multi varite analaysis
     - correlation etc
- Now we need to learn ferature Engineering
     - we will create a new column foe better ML model
     - we will perform the **encoding** which is convert Categorival to Numerical data
     - we will do **Transformatiom**
     - we will perfrom **Scaling: Standardlization and Normalayzetion**
     - We will perform Scalling: Standardization and Normalization
     - We will perform the Missing values analysis
     - Simply feature engneering means our data will be modified4

# %% [markdown]
# **Emcoding**
# - Encoding means convert categorical data to Numerical data
# - ML/DL or any madel works based on maths
# - Modul can not understand english
# - so it is very imp to convert categorical lables to numerical values................
# - .
# - .
# -

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path="winequality_red.csv"
wine_df=pd.read_csv(path)
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
path="visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %% [markdown]
# - Certified should assigne as 0
# - Denide should assigne as 1

# %%
d={'Certifide': 0,'Denide': 1}
d
# Out:
# {'Certifide': 0, 'Denide': 1}

# %%
visa_df['case_status']=visa_df['case_status'].map(d)
visa_df['case_status']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 25475   NaN
# 25476   NaN
# 25477   NaN
# 25478   NaN
# 25479   NaN
# Name: case_status, Length: 25480, dtype: float64

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
d={}
d['Asia']=0
d['Africa']=1
d['North America']=2
d['Europe']=3
d['South America']=4
d['Oceania']=5
d
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
label=visa_df['continent'].unique()

# %%
lables=sorted(visa_df['continent'].unique())
d={}
for i,j in enumerate(lables):
    d[j]=i
d
# Out:
# {'Africa': 0,
#  'Asia': 1,
#  'Europe': 2,
#  'North America': 3,
#  'Oceania': 4,
#  'South America': 5}

# %%
l=["Apple","Banana"]
for i in range(len(1)):
# Out:
#   Cell In[12], line 3
#
#     ^
# _IncompleteInputError: incomplete input

# %%
lables=sorted(visa_df['continent'].unique())
d={j:i for i,j in enumerate(lables)}
visa_df['continent']=visa_df['continent'].map(d)

# %%
path="visadataset.csv"
visa_df=pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns


# i need to repeate above 3 line for all cat column
# except case_id
for i in cat:
    lables=sorted(visa_df[i].unique())
    d={j:i for i,j in enumerate(lables)}
    visa_df[i]=visa_df[i].map(d)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
#   1 reade the data
get the cat column
for loop on cat start with 1
# lables=sorted(visa_df['continent'].unique())
# d={j:i for i,j in enumerate(lables)}
# visa_df[i]=visa_df[i].map(d)

# %% [markdown]
# ### LableEncoder
# - lableEnocder is a method will convert lables to numeric values
# - It is under package: **sklearn (sickit-learn)**
#   - the class Name is : preprocessing
#      - the method name : LabelEncoder

# %%
# from <package>.<class> import<Method>
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# - step-1: impoet the method
# -  step-2: save the method
# -  step-3: apply fit transform
# - **fit transform**
#   - fit means find the logic
#     - in above example fit means cerate mapper or dict
#   -

# %%
path="visadataset.csv"
visa_df=pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns

from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder

for i in cat:
    le=LabelEncoder()
    
    visa_df['continent']=le.fit_transform(visa_df['continent'])
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ### OneHotEncoder
# - First how many lables are there in a column
# - that  many nwe
# - for ex case status has two
#   - Certified
#   - Denied
# - So It will create Two new extra columns
#   - csae_states_Cretified
#   - case_states_Denide
# - At a time one column value become 1 other column value become 0
# - this means a *OneHotEncoder*
#
# |case_status|Case_status_Certified|Case_status_Denied|
# |-|-|-|
# |Certified|1|0|
# |Denied|0|1|

# %% [markdown]
# ### pd.get_dummies

# %%
path="visadataset.csv"
visa_df=pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns
pd.get_dummies(visa_df['case_status'],dtype=int)
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %%
visa_df['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object
